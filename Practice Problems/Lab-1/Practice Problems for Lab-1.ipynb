# %% [markdown]
# <div style="text-align:center">
#     <h1> Practice Problems: Lab-1 </h1>
# </div>

# %% [markdown]
# ## Ground rules
#
# Use only the constructs seen in the lectures: literals, the operators `+`, `-`, `*`, `+.`, comparisons (`=`, `<`, `<=`, `>`, `>=`), string concatenation `^`, `if ... then ... else`, `let` / `let ... in`, anonymous functions (`fun x -> e`), function application, `let rec` (and `let rec ... and ...` for mutual recursion), and `assert`.
#
# No library functions are allowed (except where a question explicitly allows one).
#
# Each exercise comes with a cell of `assert` tests. Write your solution in the empty cell, run it, then run the test cell: your solution is correct when all the asserts evaluate to `()` without raising an error. You are encouraged to add more asserts of your own.

# %% [markdown]
# ## E1. Maximum of two, then three
#
# Write a function `max2 : int -> int -> int` that returns the larger of its two arguments. Then write `max3 : int -> int -> int -> int` that returns the largest of three arguments **by reusing `max2`** (i.e. you should not use `if ... then ... else`).

# %%
(* Write your solution here *)

# %% [markdown]
# #### Tests for E1

# %%
assert (max2 3 7 = 7);;
assert (max2 7 3 = 7);;
assert (max3 1 9 5 = 9);;
assert (max3 9 1 5 = 9);;
assert (max3 1 5 9 = 9);;

# %% [markdown]
# ## E2. Absolute value
#
# Write a function `abs_val : int -> int` that returns the absolute value of its argument.

# %%
(* Write your solution here *)

# %% [markdown]
# #### Tests for E2

# %%
assert (abs_val 5 = 5);;
assert (abs_val (-5) = 5);;
assert (abs_val 0 = 0);;

# %% [markdown]
# ## E3. Sign of a float
#
# Write a function `sign : float -> int` that returns `-1` if its argument is negative, `0` if it is zero, and `1` if it is positive.
#
# (Note that the *argument* is a `float` but the *result* is an `int`)
#
# *Hint: You can use relational operators such as `<` and `=` directly on `float` values.*

# %%
(* Write your solution here *)

# %% [markdown]
# #### Tests for E3

# %%
assert (sign 3.14 = 1);;
assert (sign (-2.5) = -1);;
assert (sign 0.0 = 0);;

# %% [markdown]
# ## E4. Building strings
#
# Write a function `describe : string -> int -> string` such that `describe "Aman" 18` returns a sentence of the form
#
# ```
# "Aman is 18 years old."
# ```
#
# built with `^`. You will need `string_of_int : int -> string` to convert the age. This is the only library function you may use here.

# %%
(* Write your solution here *)

# %% [markdown]
# #### Tests for E4

# %%
assert (describe "Aman" 18 = "Aman is 18 years old.");;
assert (describe "Ada" 36 = "Ada is 36 years old.");;

# %% [markdown]
# ## E5. Square of sum
#
# Write a function `square_of_sum : int -> int -> int` that computes `(x + y) * (x + y)`. **Requirement:** the sum `x + y` must be computed only once, by binding it to a local name with `let ... in`.

# %%
(* Write your solution here *)

# %% [markdown]
# #### Tests for E5

# %%
assert (square_of_sum 2 3 = 25);;
assert (square_of_sum (-1) 1 = 0);;

# %% [markdown]
# ## E6. Anonymous functions
#
# **(a)** Define a function `triple : int -> int` that multiplies its argument by 3. **Requirement:** you must write it in the form `let triple = fun ...`, i.e., as a name bound to an anonymous function (not `let triple x = ...`).
#
# **(b)** In the second cell below, write a **single expression** (no `let` anywhere) that applies an anonymous doubling function directly to the argument `7`. The cell itself should evaluate to `14`.

# %%
(* (a) Write your solution here *)

# %%
(* (b) Write your single expression here *)

# %% [markdown]
# #### Tests for E6

# %%
assert (triple 5 = 15);;

# %% [markdown]
# ## E7. Partial application
#
# The definitions of `add` and `mul` are given in the cell below (run it first).
#
# Using **only partial applications** of `add` and `mul` define:
#
# * `succ : int -> int` (adds 1)
# * `double : int -> int` (multiplies by 2)
# * `neg : int -> int` (negates)
#
# That is, you should not use `fun`, and your definitions should not use any parameters

# %%
let add x y = x + y
let mul x y = x * y

# %%
(* Write your solution here *)

# %% [markdown]
# #### Tests for E7

# %%
assert (succ 41 = 42);;
assert (double 21 = 42);;
assert (neg 42 = -42);;

# %% [markdown]
# ## E8. Linear equation
#
# Write a function `linear : int -> int -> (int -> int)` such that `linear a b` returns *a function* that maps `x` to `a * x + b`.
#
# Then use `linear` (with partial application, no `fun`) to define `add_five : int -> int`, the function that adds 5.
#
# *Think about it: why does `linear 0 7 100` in the test cell parse the way it does? Recall that function application is left associative.*

# %%
(* Write your solution here *)

# %% [markdown]
# #### Tests for E8

# %%
let f = linear 2 3;;
assert (f 10 = 23);;
assert (linear 0 7 100 = 7);;
assert (add_five 37 = 42);;

# %% [markdown]
# ## E9. Function Composition
#
# Write a function `compose : (int -> int) -> (int -> int) -> int -> int` such that `compose f g x` computes `f (g x)`. Annotate the parameters as shown below so the types come out as intended:
#
# ```ocaml
# let compose (f : int -> int) (g : int -> int) = ...
# ```
#
# Then define `add_then_double : int -> int` as `compose double succ` (using your functions from E7).

# %%
(* Write your solution here *)

# %% [markdown]
# #### Tests for E9

# %%
assert (compose succ double 5 = 11);;  (* succ (double 5) *)
assert (compose double succ 5 = 12);;  (* double (succ 5) *)
assert (add_then_double 20 = 42);;

# %% [markdown]
# ## E10. Recursive functions
#
# **(a)** Write a recursive function `mul_by_add : int -> int -> int` that computes `x * y` for `y >= 0` **without using `*`**. That is, you should use only `+`, recursion, and `if`.
#
# **(b)** Write a recursive function `repeat : string -> int -> string` such that `repeat s n` is the string `s` concatenated `n` times (and `""` when `n <= 0`).

# %%
(* Write your solution here *)

# %% [markdown]
# #### Tests for E10

# %%
assert (mul_by_add 6 7 = 42);;
assert (mul_by_add 5 0 = 0);;
assert (mul_by_add 0 5 = 0);;
assert (repeat "ab" 3 = "ababab");;
assert (repeat "x" 1 = "x");;
assert (repeat "hello" 0 = "");;

# %% [markdown]
# ## E11. Mutually recursive functions
#
# Using `let rec ... and ...`, write a function `alternate : int -> string` such that `alternate n` is the string of length `n` that alternates the letters `"a"` and `"b"`, always starting with `"a"` (and is `""` for `n <= 0`).
#
# *Hint: define two mutually recursive helpers: one that produces a string starting with `"a"`, one that produces a string starting with `"b"`, and let `alternate` call the first.*

# %%
(* Write your solution here *)

# %% [markdown]
# #### Tests for E11

# %%
assert (alternate 1 = "a");;
assert (alternate 2 = "ab");;
assert (alternate 5 = "ababa");;
assert (alternate 0 = "");;

# %% [markdown]
# ## E12. Tail recursion
#
# **(a)** Your `repeat` from E10(b) builds up one stack frame per repetition, so `repeat "x" 10000000` may overflow the stack. Using the recipe from the lecture (helper function + accumulator), write a tail-recursive version `repeat_tailrec` with helper `repeat_aux`.
#
# **(b)** Do the same for `mul_by_add` from E10(a): write a tail-recursive `mul_by_add_tailrec`, and check that `mul_by_add_tailrec 1 100000000` runs without a stack overflow.
#
# **(c) Challenge:** The lecture's `fib` makes *two* recursive calls, so the accumulator recipe does not apply directly. Write a tail-recursive `fib_tailrec` whose helper carries **two** accumulators: the current Fibonacci number and the next one, and steps them forward `n` times.

# %%
(* Write your solution here *)

# %% [markdown]
# #### Tests for E12

# %%
assert (repeat_tailrec "ab" 3 = "ababab");;
assert (mul_by_add_tailrec 6 7 = 42);;
assert (mul_by_add_tailrec 1 100_000_000 = 100_000_000);;
assert (fib_tailrec 10 = 55);;
assert (fib_tailrec 50 = 12586269025);;
