# %% [markdown]
# <div style="text-align:center">
# <h1> CS3100 Paradigms of Programming </h1>
# <h2> July-November 2026 </h2>
# <h2> Kartik Nagar </h2>
# </div>

# %% [markdown]
# ## What?
#
# <img src="images/paradigm.png">
#
# **Paradigms of Programming:** Different models used in programming (languages)
#
# Recall that a programming language is just an artificial language designed to communicate instructions to a computer

# %% [markdown]
# ## Have you ever wondered
#
# * Why are there so many programming languages? (with new ones being continuously developed)

# %% [markdown]
# * What is the real differentiating factor between different programming languages? (We are not talking about syntactic differences)

# %% [markdown]
# * Why don't people just use assembly language?

# %% [markdown]
# * What are the "must-have" features for any programming languages?

# %% [markdown]
# ## The oldest paradigm: Machine-dependent languages (circa 1940s)
#
# Euclid's algorithm for GCD: $$gcd(a,b) = gcd(b, a \text{ mod } b)$$
#
# GCD program in x86 machine language:
# <img src="images/gcd_machinelang.png">
#
# GCD program in x86 assembly language:
# <img src="images/gcd_assemblylang.png">

# %% [markdown]
# ## From machine dependent to machine-independent languages (circa 1950s)
#
# * Machine dependent languages were
#   + cumbersome to use
#   + needed complete rewrite of a program for every new machine
#   + led to large programs which were unmanageable by humans
#
# * Machine-independent languages were developed to make programming more easier for humans
#    + Earliest examples: **Fortran, Lisp, Algol**
#    + Needed a *compiler* for translating to a machine-dependent language

# %% [markdown]
# ## Evolution of programming languages
#
# * The revolution of structured programming (circa 1960s)
#     + `goto` based control flow of **Fortran, Cobol, Basic** was replaced with `while` loops, `switch (case)` statements
#     + Pioneered by languages such as **C, Pascal**
# * Advent of object-oriented languages (circa 1980s)
#     + the monolithic nested block structure was replaced by a more natural object-oriented structure
#     + **C++, Java**
# * Advent of scripting languages (circa 2000s)
#    + no compilation, allows rapid development
#    + **Python, Ruby**

# %% [markdown]
# ## Most popular paradigms today
#
# * Multi-paradigm languages
#   + Allow different styles of programming in the same language
#   + Python, Java, C++, Rust
# * Functional programming languages
#   + Treating computation as mathematical evaluations
#   + Haskell, Scala, Ocaml
# * Concurrent and Reactive programming languages
#   + Managing multi-core and distributed Systems
#   + Go, Erlang

# %% [markdown]
# <img src="images/paradigms.png">
#
# Src: "Programming Paradigms for Dummies: What Every Programmer Should Know" by Peter Van Roy

# %% [markdown]
# ## Two major classes of programming language paradigms
#
# <img src="images/classification.png">

# %% [markdown]
# ## Two major classes of programming language paradigms
#
#
# Declarative languages are "higher level"
# * Programs describe **what** the computer should compute
# * Focus is more on programmer's point of view, than the implementors
# * Allows very succint, elegant code
# * No/little control on performance
#
# Imperative languages are "lower level"
# * Programs describe **how** the computer should compute
# * Allows more low-level orchestration of computer resources
# * Greater control on performance

# %% [markdown]
# ## GCD in different programming paradigms
#
# <img src="images/gcd_multilang.png">

# %% [markdown]
# # In CS3100
#
# <div style="text-align:center">
# <h2 style="color:blue"> The goal of CS3100 <h2>
# <h2> is to become a better programmer <h2>
# <h2 style="color:green"> through the study of programming languages <h2>
# </div>

# %% [markdown]
# ## What do we mean by "Programming Languages"?
#
# **Programming Languages:** Language design, implementation, semantics, compilers, interpreters, runtime systems, programming methodology, testing, verification, security, reliability ...
#
# Adjacent to **Software Engineering** in the CS family tree.

# %% [markdown]
# ## Why study Programming Languages?
#
# ### Linguistic Relativity
#
# ```
# The principle of linguistic relativity holds that the
# structure of a language affects its speakers world view
# or cognition.
# ```

# %% [markdown]
# Applying this principle to programming languages:
#
# <center>
#     <i> Programming Language shapes Programming Thought </i>
# </center>
#
# Language affects how easily ideas and computation can be expressed.
#
# **In this course, you will learn new PL concepts which will change the way you think about programming.**

# %% [markdown]
# ## Goal: Increased capacity to express ideas
#
# Different programming languages have **different features**, leading to new **software development thought processes**
#
# * Increased ability to understand obscure features, e.g. Lambda expressions in Java.
# * Choose among alternative ways to express things, based on implementation cost, readability and maintainability, etc.
# * Simulate useful features in languages that lack them.

# %% [markdown]
# ## Goal: Learn New Languages / Constructs
#
# New ways to *describe* and *organize* computation, to create programs that are:
#
# * Correct
# * Readable
# * Extendable
# * Reusable

# %% [markdown]
# ## New languages come (and go ..)
#
# * In this course, the aim is not to teach you one programming language
#   + though we will do that invariably
# * There was no
#   + Java 31 years ago
#   + C# 26 years ago
#   + Rust 18 years ago
#   + WebAssembly 10 years ago
# * _What may come next?_

# %% [markdown]
# ## Goal: Learn the Anatomy of PL
#
# * What makes a programming language?
# * Which features are *fundamental* and which are *syntactic sugar*?

# %% [markdown]
# ## Goal: How to Design new Languages
#
# New hot languages being designed in industry as we speak:
#
# * Flow, React @ Facebook
# * Rust @ Mozilla
# * TypeScript @ Microsoft
# * Swift @ Apple
# * WebAssembly @ Google + Mozilla + Microsoft

# %% [markdown]
# ## Goal: How to Design new Languages
#
# Buried in every large system is a (domain-specific) language
#
# * DB: SQL
# * Word, Excel: Formulas, Macros, VBScript
# * Emacs: LISP
# * Latex, shell scripts, makefiles, …
# * All the smart contract languages on *Blockchains*.
#
# If you work on a large system, you **will** design a new PL!

# %% [markdown]
# ## Goal: Enable You To Choose Right PL
#
# But isn’t that decided by
#
# * Libraries
# * Standards
# * Hiring
# * Your Boss?!
#
# Learn about different programming paradigms so that you can make **informed** choices

# %% [markdown]
# ## Course Syllabus
#
# * **Functional Programming:** OCaml & Lambda Calculus
# * **Logic Programming:** Prolog

# %% [markdown]
# ## Are OCaml & Prolog the best choices?
#
# Asking
#
# <center> <h3> What is the best programming language? </h3> </center>
#
# is similar to asking
#
# <center> <h3> What is the best car? </h3> </center>
#
# </br> </br>
#
# <center> <h3> What is the best shoe? </h3> </center>

# %% [markdown]
# ## Cars/Shoes
#
# * Different cars are good at rather different things:
#   + Winning a Formula 1 race
#   + Driving to the mall
#   + off-roading
#   + Hauling a mattress
# * Same with shoes:
#   + Playing cricket
#   + Going to the beach
#   + Going to a formal dinner

# %% [markdown]
# ## Five aspects of learning a PL
#
# 1. **Syntax:** How do you write language constructs?
# 2. **Semantics:** What do programs mean? (Type checking, evaluation rules)
# 3. **Idioms:** What are typical patterns for using language features to express your computation?
# 4. **Libraries:** What facilities does the language (or a third-party project) provide as “standard”? (E.g., file access, data structures)
# 5. **Tools:** What do language implementations provide to make your job easier? (E.g., top-level, debugger, GUI editor, ...)
#
#
# * Breaking a new PL down into these pieces makes it easier to learn.

# %% [markdown]
# ## Our Focus
#
# We will focus on **semantics** and **idioms**
#
# * **Semantics:** Correct reasoning about programs, interfaces, and compilers requires a precise knowledge of semantics
#   + Not “I feel that conditional expressions might work like this”
#   + Not “I like curly braces more than parentheses”
#   + Much of software development is  precise interfaces
# * **Idioms:** Common _patterns_ of programming
#   + Best to see in multiple settings, including where they shine

# %% [markdown]
# ## Not our focus
#
# **Libraries** and **tools** are a secondary: throughout your career you’ll learn new ones on the job every year
#
# * **Syntax** is a "fact"; almost always boring
#   + People obsess over subjective preferences
#   + There is no point in complaining about syntax

# %% [markdown]
# ## Course Resources
#
#
# * Course Github page: https://github.com/Kartiknagar/CS3100_o26
#     + It will contain all the lectures and assignments.
# * Course Moodle page
#   + Assignment submissions
# * We use [EDstem](https://edstem.org/) as an online discussion platform for the course.
#   + All the registered students have already been enrolled. If you are not enrolled yet, click on the following: https://edstem.org/us/join/8jtM3Q.
#   + All official course communication will be through EDstem.
#   + You can post any query (technical or administrative) regarding the course on the space (there is also a feature to post anonymously).

# %% [markdown]
# ## Course Logistics
#
# ### Programming Assignments
#
# * For programming assignments, we will follow a dual mode procedure:
# * **Take-home practice problems** will be released first.
#     + You will be given a time of **1 week** for solving the problems.
#     + You are expected to try to solve the problems **on your own**.
#     + If you get stuck, you can get help from **friends/TAs/instructor/LLM**.
#     + **Solutions to take-home problems will not be evaluated.**
# * There will an **in-lab session** exactly 1 week after the release of take-home problems.
#     + You will be required to solve some problems which will be **based on the take-home problems**.
#     + There will be **no internet access** in the lab.
#     + You will have access to the **lecture slides**.
#     + You will have access to **your solutions** to the take-home problems.

# %% [markdown]
# ## Course Logistics
#
# ### Tentative Lab Schedule
#
# Labs will be held during the Wednesday 10-10:50 am slot in DCF on a bi-weekly basis:
#
# 1. Aug 12
#
# 1. Sep 2
#
# 1. Sep 16
#
# 1. Sep 30
#
# 1. Oct 14
#
# 1. Oct 28

# %% [markdown]
# ## Course Logistics
#
# ### Lectures
#
# * Slot E (Tue 11 AM, Wed 10 AM, Thu 8 AM, Fri 5 PM)
#     * For weeks without lab session: Tue 11, Wed 10, Thu 8 (i.e. **no lecture on Friday**)
#     * For weeks with lab session: Tue 11, Thu 8, Fri 5 (i.e. **no lecture on Wednesday**)
# * Delivered through interactive Jupyter notebooks.
# * Instruction for setting up available on [course github page](https://github.com/Kartiknagar/CS3100_o26).
# * You can practice inside the lecture slides itself!
# * Each lecture's notebook will be uploaded before the slot.

# %% [markdown]
# ## Course Logistics
#
# ### Grading
#
# * Lab Assignments (best 5 out of 6): 40%
# * Quiz 1 and 2 : 30% (15% each)
# * Endsem: 30%
#
# * Attendance: as per the institute policy

# %% [markdown]
# ## Software
#
# * We will use OCaml and Prolog in this course.
# * Both are already installed on the course docker image. Instructions for running the docker image are present on the course [github page](https://github.com/Kartiknagar/CS3100_o26).
#     * You need not install OCaml and Prolog on your machines.
#     * The assignments will also be done on Jupyter notebook pages.

# %% [markdown]
# ## Reference Books
#
# * Programming Language Pragmatics, Third Edition, by Michael L. Scott, Morgan Kaufmann, 2009
# * Programming Languages: Design and Implementation (4th Edition), by Terrence W. Pratt, Marvin V. Zelkowitz, Pearson, 2000
# * Programming Languages: Concepts and Constructs; 2nd Edition, Ravi Sethi, Pearson Education Asia, 1996.

# %% [markdown]
# ## Acknowledgements
#
# The course heavily borrows material from an earlier offering by [KC Sivaramakrishnan](https://kcsrk.info/) and the course CS3100 from Cornell University.
